# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
import seaborn as sns

x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.65100299 2.60569781 2.81780071 2.52934018 2.71672083 2.46353314
#  2.06159881 2.67698555 2.72249455 2.09717983]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def interval_uniform(bottom, ceiling, count):
    return uniform(bottom, ceiling).rvs(count)

uniform_1=interval_uniform(10, 15,100)

# %%
uniform_2=interval_uniform(10, 60,1000)

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# - The main difference is that the second one is more uniformously horizontal, this is because the more population, the more it tends to the perfect distribution.

# %%
sns.histplot(x = uniform_1);

# %%
sns.histplot(x = uniform_2);

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm
def interval_normal(mean,deviation,count):
    normal=norm(mean,deviation)
    sample=normal.rvs(count)
    return sample

# %%
sample_1=interval_normal(10,1,1000)
sample_1
# Out:
# array([ 9.85195703,  9.29974985, 10.50551294,  8.66253217,  9.52757263,
#         9.87567954,  9.21313526, 10.40802114,  9.28806809,  8.87507971,
#        10.18880179,  9.95954583, 10.18884727, 10.18888374, 11.77454408,
#         9.12999578,  8.90655278,  9.18563751, 10.0198202 , 10.22313818,
#         8.96075628, 10.35629675, 11.14578279, 10.03327338, 10.62385131,
#         9.32454152, 11.43754549,  9.08415693,  8.28447354,  7.96398638,
#         8.77864402, 10.43527392, 10.02319757,  9.53585345, 10.83602194,
#        10.73932342,  9.78281864, 10.61395625,  9.02690589, 10.65854923,
#        10.88597553, 10.22734315, 11.17927777, 11.13095389, 11.5829745 ,
#         9.31919581, 12.7124236 ,  9.49157711, 10.59343175, 10.33290363,
#         9.92541826,  9.36046327,  9.45653155, 12.51110315, 10.90514887,
#         9.25302544, 10.95134854,  9.07836607,  8.70623372,  9.25222773,
#         9.97336096,  8.70344935,  8.88857884,  8.27607638, 10.95503249,
# ...

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# - The first one is less spread, since it has a lower deviation the results are more concentrated in the middle
# -

# %%
sample_2=interval_normal(10,50,1000)

# %%
sns.histplot(x = sample_1, palette="Blues")
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(x = sample_2, palette="Blues")
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# !ls
import pandas as pd
# Out:
# ed.png       main.ipynb   nd.png       ud.png       vehicles.csv

# %%
data=pd.read_csv("vehicles.csv")

# %%
sns.histplot(x = data["Fuel Barrels/Year"], palette="Blues", bins=50);

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
sns.histplot(x = data["CO2 Emission Grams/Mile"], palette="Blues", bins=50);

# %% [markdown]
# 3. Combined MPG

# %%
sns.histplot(x = data["Combined MPG"], palette="Blues", bins=50);

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %% [markdown]
# ## The third one, since the kurtosis value is close to 3, which is the ideal value for a normal distribution. We can also see visually that is uniformously normal.

# %%
from scipy.stats import shapiro
from scipy.stats import skew, kurtosis

kurt_1 = kurtosis(data["CO2 Emission Grams/Mile"])
skewness_1 = skew(data["CO2 Emission Grams/Mile"])
print(skewness_1)
print(kurt_1)
# Out:
# 0.7416608937445333
# 1.2632401888522526

# %%
kurt_2 = kurtosis(data["Fuel Barrels/Year"])
skewness_2 = skew(data["Fuel Barrels/Year"])

print(skewness_2)
print(kurt_2)
# Out:
# 0.6382445784906976
# 1.467913801930207

# %%
from scipy.stats import shapiro
from scipy.stats import skew, kurtosis
skewness_3 = skew(data["Combined MPG"])
kurt_3 = kurtosis(data["Combined MPG"])
print(skewness_3)
print(kurt_3)
# Out:
# 1.0677281511016457
# 2.722005828121911

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
from scipy.stats import expon
def exp_interval(mean,count):
    distribution=expon(mean)
    distribution=distribution.rvs(count)
    return distribution

sample_1=exp_interval(2,1000)
sample_2=exp_interval(200,1000)

# %% [markdown]
# How are the two distributions different?

# %%
## I REALLY DON'T KNOW RICK, WOULD BE GREAT TO KNOW IT!

# %%
sns.histplot(x = sample_1, palette="Blues", bins=100);

# %%
sns.histplot(x = sample_2, palette="Blues", bins=100);

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
amount=expon(1/10)
prob_1=amount.cdf(15)
prob_1
# Out:
# 0.9999996619256516

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
prob_2=1-prob_1
prob_2
# Out:
# 3.3807434840493755e-07
